# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt
from keras.applications.mobilenet import preprocess_input

# %%
# loading the Deep Learning Model

model = tf.keras.models.load_model('models/palmistry_model_v1.h5')

# %%
# loading the image to predict !

image_path = 'test/test_1.jpg'

image = cv2.imread(image_path)
plt.imshow(image)

# %%
# preprocessing the image
image = tf.image.resize(
    image, (224, 224), method=tf.image.ResizeMethod.BILINEAR, preserve_aspect_ratio=False,
    antialias=True, name=None
)
image.shape
# Out:
# TensorShape([224, 224, 3])

# %%
image_new= np.asarray(image).astype('float32').reshape((1, 224, 224, 3))
image_new.shape
# Out:
# (1, 224, 224, 3)

# %%
# Prediction

model.predict(image_new)
# Out:
# array([[0.9846497]], dtype=float32)
